# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from pathlib import Path
# %matplotlib inline
import seaborn as sns
import pandas as pd
import numpy as np
import requests
import time
from sklearn.linear_model import LinearRegression

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="
response = requests.get(query_url).json()
lat = []
lng = []
max_temp = [] 
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

for i, city in enumerate(cities, 1):
    print(f"Processing city {i}: {city}")
    if i % 59 == 0:
        time.sleep(61)
    response = requests.get(query_url + city).json()
    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except KeyError:
        print(f"Data not found for {city}. Removing from the list...")
        continue
    cities.remove(city)
# Out:
# Processing city 1: bilibino
# Processing city 2: port-aux-francais
# Processing city 3: west island
# Processing city 4: quelimane
# Processing city 5: pitimbu
# Processing city 6: atafu village
# Processing city 7: bassila
# Processing city 8: lihue
# Processing city 9: taiohae
# Data not found for taiohae. Removing from the list...
# Processing city 10: peitz
# Processing city 11: udachny
# Processing city 12: cargados carajos
# Data not found for cargados carajos. Removing from the list...
# Processing city 13: ushuaia
# Processing city 14: kingston
# Processing city 15: kulia village
# Data not found for kulia village. Removing from the list...
# Processing city 16: sitka
# Processing city 17: punta arenas
# Processing city 18: ulanhot
# Processing city 19: tazovsky
# Processing city 20: pisco
# Processing city 21: arraial do cabo
# Processing city 22: guane
# Processing city 23: mutuali
# Processing city 24: kalmunai
# Processing city 25: dzuunharaa
# Processing city 26: sungai penuh
# Processing city 27: saipan
# Processing city 28: bikenibeu village
# Processing city 29: potiskum
# Processing city 30: port alfred
# Processing city 31: kalispell
# Processing city 32: whitehorse
# Processing city 33: huocheng
# Data not found for huocheng. Removing from the list...
# Processing city 34: davlekanovo
# Processing city 35: ocean pointe
# Data not found for ocean pointe. Removing from the list...
# Processing city 36: hasaki
# Processing city 37: gueltat zemmour
# Data not found for gueltat zemmour. Removing from the list...
# Processing city 38: sandnessjoen
# Processing city 39: nadi
# Processing city 40: port augusta
# Processing city 41: luderitz
# Processing city 42: bay roberts
# Processing city 43: klaksvik
# Processing city 44: bajil
# Processing city 45: makokou
# Processing city 46: guerrero negro
# Processing city 47: kataragama
# Data not found for kataragama. Removing from the list...
# Processing city 48: codrington
# Processing city 49: mukah
# Data not found for mukah. Removing from the list...
# Processing city 50: nar'yan-mar
# Processing city 51: san patricio
# Processing city 52: orebro
# Processing city 53: san juan de uraba
# Processing city 54: ivdel'
# Processing city 55: egilsstadir
# Processing city 56: isle of lewis
# Data not found for isle of lewis. Removing from the list...
# Processing city 57: bethel
# Processing city 58: tete
# Processing city 59: usinsk
# Processing city 60: vilyuchinsk
# Processing city 61: portland
# Processing city 62: lisala
# Processing city 63: hamilton
# Processing city 64: mandalgovi
# Processing city 65: tailai
# Processing city 66: kolwezi
# Processing city 67: bel ombre
# Processing city 68: kuraymah
# Processing city 69: charters towers
# Processing city 70: bereket
# Processing city 71: irymple
# Processing city 72: hajin
# Processing city 73: remire-montjoly
# Processing city 74: polyarnyy
# Processing city 75: iskilip
# Processing city 76: anadyr
# Processing city 77: igarka
# Processing city 78: shira
# Processing city 79: strathmore
# Processing city 80: vila velha
# Processing city 81: alaior
# Processing city 82: rabo de peixe
# Processing city 83: kavalerovo
# Processing city 84: kongsvinger
# Processing city 85: vingt cinq
# Data not found for vingt cinq. Removing from the list...
# Processing city 86: selfoss
# Processing city 87: ivolginsk
# Processing city 88: aitape
# Processing city 89: moyynkum
# Processing city 90: socorro
# Processing city 91: san luis de la loma
# Processing city 92: sydney mines
# Processing city 93: amarante
# Processing city 94: zabid
# Processing city 95: de aar
# Processing city 96: turpan
# Processing city 97: la puebla de montalban
# Processing city 98: oppdal
# Processing city 99: illizi
# Processing city 100: yangor
# Data not found for yangor. Removing from the list...
# Processing city 101: wagar
# Processing city 102: forio
# Processing city 103: wolgast
# Processing city 104: fonadhoo
# Data not found for fonadhoo. Removing from the list...
# Processing city 105: renk
# Data not found for renk. Removing from the list...
# Processing city 106: deschutes river woods
# Processing city 107: bamboo flat
# Processing city 108: moose jaw
# Processing city 109: moroto
# Processing city 110: san luis
# Processing city 111: cheremushki
# Processing city 112: beira
# Processing city 113: puerto quijarro
# Processing city 114: barentu
# Processing city 115: valdez
# Processing city 116: taman rajawali
# Data not found for taman rajawali. Removing from the list...
# Processing city 117: freetown
# Processing city 118: great yarmouth
# Processing city 119: mahina
# Processing city 120: ji'an
# Processing city 121: constantia
# Processing city 122: pasargad
# Data not found for pasargad. Removing from the list...
# Processing city 123: selkirk
# Processing city 124: coxen hole
# Processing city 125: eureka
# Processing city 126: limulunga
# Processing city 127: suncho corral
# Processing city 128: atyashevo
# Processing city 129: viedma
# Processing city 130: jimenez
# Processing city 131: lata
# Processing city 132: ramhormoz
# Processing city 133: agat village
# Processing city 134: al bardiyah
# Processing city 135: formosa do rio preto
# Processing city 136: gao
# Processing city 137: launceston
# Processing city 138: pakxan
# Processing city 139: lindsay
# Processing city 140: breves
# Processing city 141: chibuto
# Processing city 142: al jawf
# Processing city 143: saguenay
# Processing city 144: itoman
# Processing city 145: ola
# Processing city 146: atvidaberg
# Processing city 147: pechora
# Processing city 148: hermiston
# Processing city 149: pinehurst
# Processing city 150: beberibe
# Processing city 151: mount isa
# Processing city 152: pacocha
# Processing city 153: yeppoon city centre
# Data not found for yeppoon city centre. Removing from the list...
# Processing city 154: zakamensk
# Processing city 155: puerto aysen
# Processing city 156: bargara
# Data not found for bargara. Removing from the list...
# Processing city 157: durant
# Processing city 158: lerwick
# Processing city 159: douglas
# Processing city 160: ambagarh chauki
# Processing city 161: christchurch
# Processing city 162: huautla de jimenez
# Processing city 163: garla-mare
# Processing city 164: broome
# Processing city 165: carbonear
# Processing city 166: kish
