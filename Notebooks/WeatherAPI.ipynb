# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from config import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 569

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="
response = requests.get(query_url).json()
lat = []
lng = []
max_temp = [] 
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
city_name = []

for i, city in enumerate(cities, 1):
    print(f"Processing city {i}: {city}")
    if i % 59 == 0:
        time.sleep(61)
    response = requests.get(query_url + city).json()
    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        city_name.append(city)
        
    except KeyError:
        print(f"Data not found for {city}. Skipping...")
        continue
# Out:
# Processing city 1: aasiaat
# Processing city 2: hermanus
# Processing city 3: laibin
# Processing city 4: utrik
# Processing city 5: puerto natales
# Processing city 6: ngaoundere
# Processing city 7: rio grande
# Processing city 8: atafu village
# Processing city 9: port-aux-francais
# Processing city 10: tura
# Processing city 11: lebu
# Processing city 12: ushuaia
# Processing city 13: ta`u
# Processing city 14: waitangi
# Processing city 15: hanceville
# Processing city 16: levokumskoye
# Processing city 17: sao jose da coroa grande
# Processing city 18: olonkinbyen
# Processing city 19: sechura
# Processing city 20: udachny
# Processing city 21: carnarvon
# Processing city 22: bethel
# Processing city 23: kachug
# Processing city 24: iqaluit
# Processing city 25: taiohae
# Data not found for taiohae. Skipping...
# Processing city 26: isafjordur
# Processing city 27: flin flon
# Processing city 28: kone
# Processing city 29: grytviken
# Processing city 30: kulia village
# Data not found for kulia village. Skipping...
# Processing city 31: fale old settlement
# Processing city 32: murun-kuren
# Processing city 33: college
# Processing city 34: maturin
# Processing city 35: adamstown
# Processing city 36: yangjiang
# Processing city 37: bredasdorp
# Processing city 38: ilulissat
# Processing city 39: morehead city
# Processing city 40: alo
# Processing city 41: albany
# Processing city 42: blackmans bay
# Processing city 43: bowen
# Processing city 44: thompson
# Processing city 45: pisco
# Processing city 46: mata-utu
# Processing city 47: kenora
# Processing city 48: enewetak
# Processing city 49: hilo
# Processing city 50: margaret river
# Processing city 51: edinburgh of the seven seas
# Processing city 52: yellowknife
# Processing city 53: gadzhiyevo
# Processing city 54: namibe
# Processing city 55: usogorsk
# Processing city 56: hradyz'k
# Processing city 57: takamaka
# Data not found for takamaka. Skipping...
# Processing city 58: touros
# Processing city 59: caribou
# Processing city 60: wau
# Processing city 61: avarua
# Processing city 62: illizi
# Processing city 63: hawaiian paradise park
# Processing city 64: tiksi
# Processing city 65: port mathurin
# Processing city 66: guarapari
# Processing city 67: ust-nera
# Processing city 68: port elizabeth
# Processing city 69: kodiak
# Processing city 70: mbanza-ngungu
# Processing city 71: pallisa
# Processing city 72: hoemul-li
# Processing city 73: invercargill
# Processing city 74: new norfolk
# Processing city 75: ekibastuz
# Processing city 76: georgetown
# Processing city 77: baud
# Processing city 78: bilibino
# Processing city 79: ebersbach an der fils
# Processing city 80: vorgashor
# Processing city 81: hammerfest
# Processing city 82: ushtobe
# Processing city 83: valparaiso
# Processing city 84: durban
# Processing city 85: mirny
# Processing city 86: vingt cinq
# Data not found for vingt cinq. Skipping...
# Processing city 87: kununurra
# Processing city 88: klyuchi
# Processing city 89: padang
# Processing city 90: haiku-pauwela
# Processing city 91: coquimbo
# Processing city 92: sonsorol village
# Data not found for sonsorol village. Skipping...
# Processing city 93: west island
# Processing city 94: nova sintra
# Processing city 95: papatowai
# Processing city 96: zangguy
# Data not found for zangguy. Skipping...
# Processing city 97: bardai
# Processing city 98: keflavik
# Processing city 99: shalkar
# Processing city 100: lincoln city
# Processing city 101: east london
# Processing city 102: savave village
# Data not found for savave village. Skipping...
# Processing city 103: 'ohonua
# Data not found for 'ohonua. Skipping...
# Processing city 104: raja
# Processing city 105: puerto baquerizo moreno
# Processing city 106: la'ie
# Processing city 107: myitkyina
# Processing city 108: tondano
# Processing city 109: iskateley
# Processing city 110: rio gallegos
# Processing city 111: acarau
# Processing city 112: jamestown
# Processing city 113: rosarito
# Processing city 114: muisne
# Processing city 115: labrador city
# Processing city 116: kruisfontein
# Processing city 117: derzhavinsk
# Processing city 118: padam
# Data not found for padam. Skipping...
# Processing city 119: santa elena de uairen
# Processing city 120: burang
# Processing city 121: st. john's
# Processing city 122: krasnik
# Processing city 123: chelmno
# Processing city 124: tolanaro
# Processing city 125: colwyn bay
# Processing city 126: lucheng
# Processing city 127: calipatria
# Processing city 128: carahue
# Processing city 129: cabo san lucas
# Processing city 130: sanquelim
# Processing city 131: port alfred
# Processing city 132: stanley
# Processing city 133: kapuskasing
# Processing city 134: sparta
# Processing city 135: kapa'a
# Processing city 136: minas de marcona
# Processing city 137: talnakh
# Processing city 138: south hedland
# Processing city 139: valentin gomez farias
# Processing city 140: bechar
# Processing city 141: rangpur
# Processing city 142: tsiombe
# Processing city 143: tulun
# Processing city 144: mazouna
# Processing city 145: mohale's hoek
# Processing city 146: buala
# Processing city 147: bereket
# Processing city 148: bonthe
# Processing city 149: pacific grove
# Processing city 150: skelleftea
# Processing city 151: dalian
# Processing city 152: kitami
# Processing city 153: ust-tsilma
# Processing city 154: ribeira grande
# Processing city 155: hanzhong
# Processing city 156: weno
# Processing city 157: akbou
# Processing city 158: oliva de la frontera
# Processing city 159: yagry
# Data not found for yagry. Skipping...
# Processing city 160: wailua homesteads
# Processing city 161: hacilar
# Processing city 162: mucumpiz
# Processing city 163: minbu
# Processing city 164: praia da vitoria
# Processing city 165: strezhevoy
# Processing city 166: port lincoln
# Processing city 167: puerto ayora
# Processing city 168: sur
# Processing city 169: kavaratti
# Processing city 170: sabang
# Processing city 171: bathsheba
# Processing city 172: lampazos de naranjo
# Processing city 173: uturoa
# Processing city 174: khandyga
# Processing city 175: mount isa
# Processing city 176: geraldton
# Processing city 177: nadym
# Processing city 178: tamala
# Processing city 179: yarkovo
# Processing city 180: ola
# Processing city 181: kuala kedah
# Processing city 182: nantucket
# Processing city 183: balakhta
# Processing city 184: alice springs
# Processing city 185: dudinka
# Processing city 186: pangody
# Processing city 187: lindsay
# Processing city 188: igarape acu
# Processing city 189: pontevedra
# Processing city 190: freeport
# Processing city 191: san patricio
# Processing city 192: fasa
# Processing city 193: corner brook
# Processing city 194: lihue
# Processing city 195: pacocha
# Processing city 196: afaahiti
# Processing city 197: mahebourg
# Processing city 198: tyre
# Processing city 199: san andres
# Processing city 200: saudarkrokur
# Processing city 201: kupino
# Processing city 202: santo antonio do ica
# Processing city 203: jose mariano jimenez
# Data not found for jose mariano jimenez. Skipping...
# Processing city 204: ancud
# Processing city 205: panaba
# Processing city 206: flying fish cove
# Processing city 207: kharkhorin
# Processing city 208: caleta de carquin
# Processing city 209: klyavlino
# Processing city 210: hithadhoo
# Processing city 211: port saint john's
# Processing city 212: san antonio del estrecho
# Data not found for san antonio del estrecho. Skipping...
# Processing city 213: daloa
# Processing city 214: longyearbyen
# Processing city 215: hayma'
# Data not found for hayma'. Skipping...
# Processing city 216: takab
# Processing city 217: chonchi
# Processing city 218: pangai
# Processing city 219: berlin
# Processing city 220: qusmuryn
# Processing city 221: lorengau
# Processing city 222: codrington
# Processing city 223: la ronge
# Processing city 224: east end village
# Data not found for east end village. Skipping...
# Processing city 225: paithan
# Processing city 226: fortuna
# Processing city 227: antsiranana
# Processing city 228: kingston
# Processing city 229: isangel
# Processing city 230: nogliki
# Processing city 231: road town
# Processing city 232: rikaze
# Processing city 233: balurghat
# Processing city 234: glencoe
# Processing city 235: turpan
# Processing city 236: sacramento
# Processing city 237: karratha
# Processing city 238: suva
# Processing city 239: mangrol
# Processing city 240: portland
# Processing city 241: kourou
# Processing city 242: abbadia san salvatore
# Processing city 243: whitehorse
# Processing city 244: sitka
# Processing city 245: vodnyy
# Processing city 246: la passe
# Processing city 247: happy valley-goose bay
# Processing city 248: goynuk
# Processing city 249: fort frances
# Processing city 250: labytnangi
# Processing city 251: chibougamau
# Processing city 252: antofagasta
# Processing city 253: harar
# Processing city 254: kimbe
# Processing city 255: puerto san carlos
# Data not found for puerto san carlos. Skipping...
# Processing city 256: sungailiat
# Processing city 257: kerikeri
# Processing city 258: tromso
# Processing city 259: nar'yan-mar
# Processing city 260: sarmiento
# Processing city 261: badger
# Processing city 262: queenstown
# Processing city 263: forster
# Processing city 264: hasaki
# Processing city 265: fort mcmurray
# Processing city 266: idri
# Processing city 267: cockburn town
# Processing city 268: cable beach
# Data not found for cable beach. Skipping...
# Processing city 269: vorkuta
# Processing city 270: qaqortoq
# Processing city 271: hamilton
# Processing city 272: canto do buriti
# Processing city 273: salto del guaira
# Processing city 274: puerto lempira
# Processing city 275: almeirim
# Processing city 276: pechora
# Processing city 277: udon thani
# Processing city 278: augusto correa
# Processing city 279: evansville
# Processing city 280: p'ot'i
# Processing city 281: faya-largeau
# Processing city 282: isla mujeres
# Processing city 283: saint-joseph
# Processing city 284: puerto san jose
# Processing city 285: languyan
# Processing city 286: kargil
# Processing city 287: punta arenas
# Processing city 288: yuzhno-kurilsk
# Processing city 289: kolonia town
# Processing city 290: remire-montjoly
# Processing city 291: sao vicente
# Processing city 292: berdigestyakh
# Processing city 293: muscat
# Processing city 294: bayan nur
# Data not found for bayan nur. Skipping...
# Processing city 295: tsaratanana
# Processing city 296: urzhar
# Processing city 297: saipan
# Processing city 298: messini
# Processing city 299: kisangani
# Processing city 300: shingu
# Processing city 301: bodo
# Processing city 302: kasungu
# Processing city 303: nelson bay
# Processing city 304: kibre mengist
# Processing city 305: slave lake
# Processing city 306: robertsport
# Processing city 307: hagere hiywet
# Processing city 308: george town
# Processing city 309: sinabang
# Processing city 310: slavyanka
# Processing city 311: corinto
# Processing city 312: qamdo
# Processing city 313: porto belo
# Processing city 314: tokonou
# Processing city 315: egilsstadir
# Processing city 316: yurimaguas
# Processing city 317: hofors
# Processing city 318: aleppo
# Processing city 319: andergrove
# Processing city 320: dalby
# Processing city 321: merizo village
# Processing city 322: teguise
# Processing city 323: tofol
# Processing city 324: buka
# Processing city 325: jumla
# Processing city 326: kodok
# Data not found for kodok. Skipping...
# Processing city 327: porto novo
# Processing city 328: kimberley
# Processing city 329: susuman
# Processing city 330: anadyr
# Processing city 331: longquan
# Processing city 332: lincoln
# Processing city 333: toliara
# Processing city 334: ngorongoro
# Processing city 335: tubarjal
# Processing city 336: alaghsas
# Processing city 337: tranovaho
# Data not found for tranovaho. Skipping...
# Processing city 338: klaksvik
# Processing city 339: ke-macina
# Processing city 340: tual
# Processing city 341: grand falls-windsor
# Processing city 342: mount gambier
# Processing city 343: salinas
# Processing city 344: dayton
# Processing city 345: xiaolingwei
# Processing city 346: navojoa
# Processing city 347: okhotsk
# Processing city 348: fort bragg
# Processing city 349: chilecito
# Processing city 350: piney green
# Processing city 351: petropavlovsk-kamchatsky
# Processing city 352: preobrazheniye
# Processing city 353: gizo
# Processing city 354: yei
# Processing city 355: colac
# Processing city 356: brisas de zicatela
# Processing city 357: al mindak
# Processing city 358: cururupu
# Processing city 359: banikoara
# Processing city 360: kamaishi
# Processing city 361: shiraoi
# Processing city 362: vernon
# Processing city 363: tela
# Processing city 364: chiili
# Data not found for chiili. Skipping...
# Processing city 365: ladnun
# Processing city 366: waddan
# Processing city 367: hilton head island
# Processing city 368: egersund
# Processing city 369: dieppe
# Processing city 370: alotau
# Data not found for alotau. Skipping...
# Processing city 371: nuuk
# Processing city 372: rundu
# Processing city 373: cidreira
# Processing city 374: los yebenes
# Processing city 375: sogne
# Processing city 376: nadi
# Processing city 377: kroya
# Processing city 378: constitucion
# Processing city 379: kindu
# Processing city 380: aripuana
# Processing city 381: tacna
# Processing city 382: tulle
# Processing city 383: okha
# Processing city 384: kayangel
# Processing city 385: ad dilam
# Processing city 386: maintirano
# Processing city 387: sola
# Processing city 388: arraial do cabo
# Processing city 389: al ghayzah
# Processing city 390: piton saint-leu
# Processing city 391: turan
# Processing city 392: katsuura
# Processing city 393: meybod
# Processing city 394: dadonghai
# Data not found for dadonghai. Skipping...
# Processing city 395: inari
# Processing city 396: neiafu
# Processing city 397: kristiansund
# Processing city 398: siwan
# Processing city 399: el calafate
# Processing city 400: mandalgovi
# Processing city 401: vrangel'
# Processing city 402: fort st. john
# Processing city 403: kashgar
# Processing city 404: yangor
# Data not found for yangor. Skipping...
# Processing city 405: esquel
# Processing city 406: gudari
# Processing city 407: vila franca do campo
# Processing city 408: east ballina
# Processing city 409: jean-rabel
# Processing city 410: eldorado at santa fe
# Processing city 411: tazovsky
# Processing city 412: akureyri
# Processing city 413: port shepstone
# Processing city 414: nagqu
# Processing city 415: basco
# Processing city 416: manado
# Processing city 417: ulaangom
# Processing city 418: hadibu
# Processing city 419: vadso
# Processing city 420: santa cruz
# Processing city 421: susanville
# Processing city 422: benjamin constant
# Processing city 423: grajau
# Processing city 424: atlantic beach
# Processing city 425: copala
# Processing city 426: wanlaweyn
# Processing city 427: altay
# Processing city 428: pomichna
# Processing city 429: santiago papasquiaro
# Data not found for santiago papasquiaro. Skipping...
# Processing city 430: usinsk
# Processing city 431: crumlin
# Processing city 432: ciudad constitucion
# Processing city 433: costa teguise
# Data not found for costa teguise. Skipping...
# Processing city 434: torata
# Processing city 435: north bend
# Processing city 436: shalqar
# Processing city 437: kollam
# Processing city 438: st. thomas
# Processing city 439: kidal
# Processing city 440: klimavichy
# Processing city 441: tumaco
# Processing city 442: prado
# Processing city 443: charlotte amalie
# Processing city 444: westport
# Processing city 445: el nido
# Processing city 446: sodo
# Processing city 447: malango
# Processing city 448: thunder bay
# Processing city 449: benito garcia (el zorrillo)
# Data not found for benito garcia (el zorrillo). Skipping...
# Processing city 450: imbituba
# Processing city 451: shimoda
# Processing city 452: soio
# Processing city 453: the pas
# Processing city 454: korla
# Processing city 455: chinchilla
# Processing city 456: dul'durga
# Processing city 457: namsos
# Processing city 458: ha'il
# Processing city 459: betio village
# Processing city 460: acapulco de juarez
# Processing city 461: argo
# Processing city 462: tazacorte
# Processing city 463: warwick
# Processing city 464: hirado
# Processing city 465: southold
# Processing city 466: el alto
# Processing city 467: popondetta
# Processing city 468: vilyuchinsk
# Processing city 469: marsh harbour
# Processing city 470: curuzu cuatia
# Processing city 471: galveston
# Processing city 472: khorugh
# Processing city 473: walvis bay
# Processing city 474: trancoso
# Processing city 475: dunedin
# Processing city 476: port blair
# Processing city 477: monteiro
# Processing city 478: taroa
# Processing city 479: buzdyak
# Processing city 480: luderitz
# Processing city 481: lompoc
# Processing city 482: novodvinsk
# Processing city 483: nyurba
# Processing city 484: selkirk
# Processing city 485: guadalupe y calvo
# Processing city 486: san lawrenz
# Processing city 487: coron
# Processing city 488: san antonio de pale
# Processing city 489: moyynkum
# Processing city 490: yafran
# Processing city 491: hutchinson
# Processing city 492: san pedro pochutla
# Processing city 493: colesberg
# Processing city 494: puerto deseado
# Processing city 495: aguas vermelhas
# Processing city 496: margate
# Processing city 497: carboneras
# Processing city 498: melfi
# Processing city 499: betioky
# Processing city 500: al jawf
# Processing city 501: ampahana
# Data not found for ampahana. Skipping...
# Processing city 502: banda aceh
# Processing city 503: santa isabel
# Processing city 504: jasrasar
# Processing city 505: saulkrasti
# Processing city 506: toga village
# Data not found for toga village. Skipping...
# Processing city 507: west wodonga
# Processing city 508: panuco
# Processing city 509: mehtar lam
# Processing city 510: port macquarie
# Processing city 511: constantia
# Processing city 512: luba
# Processing city 513: saint-pierre
# Processing city 514: greymouth
# Processing city 515: oamaru
# Processing city 516: poli
# Processing city 517: saratamata
# Data not found for saratamata. Skipping...
# Processing city 518: hotan
# Processing city 519: trondheim
# Processing city 520: pagar alam
# Processing city 521: termas de rio hondo
# Processing city 522: sosnovo-ozerskoye
# Processing city 523: al kharijah
# Processing city 524: takoradi
# Processing city 525: ahau
# Data not found for ahau. Skipping...
# Processing city 526: taoudenni
# Processing city 527: selfoss
# Processing city 528: mermoz boabab
# Processing city 529: juneau
# Processing city 530: smithers
# Processing city 531: el granada
# Processing city 532: iquitos
# Processing city 533: howrah
# Processing city 534: manjeshvar
# Processing city 535: mazagao
# Processing city 536: revda
# Processing city 537: ugoofaaru
# Processing city 538: callao
# Processing city 539: muhoroni
# Processing city 540: khilok
# Processing city 541: kletnya
# Processing city 542: midvagur
# Processing city 543: starobaltachevo
# Processing city 544: ringkobing
# Processing city 545: baoqing
# Processing city 546: yamada
# Processing city 547: inzhavino
# Processing city 548: iwanai
# Processing city 549: quatre cocos
# Processing city 550: tchaourou
# Processing city 551: kargat
# Processing city 552: broome
# Processing city 553: posto fiscal rolim de moura
# Processing city 554: wajir
# Processing city 555: pil'na
# Processing city 556: val-d'or
# Processing city 557: bocaiuva
# Processing city 558: lata
# Processing city 559: chuzhou
# Processing city 560: nueva gerona
# Processing city 561: zhumysker
# Processing city 562: iskandar
# Processing city 563: holualoa
# Processing city 564: manistee
# Processing city 565: arroyo seco
# Processing city 566: armacao de buzios
# Processing city 567: jinka
# Processing city 568: mejit
# Processing city 569: mukalla

# %%
cities_df = pd.DataFrame({
    "City": city_name,
    "Latitude": lat,
    "Longitude": lng,
    "Max Temperature": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed,
    "Country": country,
    "Date": date
})

# %%
cities_df.to_csv("cities.csv")
